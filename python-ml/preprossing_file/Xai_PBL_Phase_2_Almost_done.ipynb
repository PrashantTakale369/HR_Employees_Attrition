# %% [markdown]
# # Library's

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\techp\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("A:\XAi_PBL\hr-insights-viz-main\python-ml\data\IBM_HR_Employee_Attrition.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\X'
# <>:1: SyntaxWarning: invalid escape sequence '\X'
# C:\Users\techp\AppData\Local\Temp\ipykernel_18976\1345998223.py:1: SyntaxWarning: invalid escape sequence '\X'
#   data = pd.read_csv("A:\XAi_PBL\hr-insights-viz-main\python-ml\data\IBM_HR_Employee_Attrition.csv")

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.shape
# Out:
# (1470, 35)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# # Data Preprocessing / Understanding

# %%
#checking corrolation and Multicolliniarity

# %%
corr = data.corr(numeric_only=True)

plt.figure(figsize=(15, 7))
sns.heatmap(corr, annot=True, cmap="YlOrBr", fmt=".1f")
plt.title("Correlation Heatmap of IBM Dataset")
plt.show()

# %% [markdown]
# ### 1) ATTRITION DISTRUBUTION

# %%
attrition_dist = data["Attrition"].value_counts().sort_index()


plt.figure(figsize=(6,6))
plt.pie(
    attrition_dist,
    labels=attrition_dist.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=["#FBAFE4", "#949494"]
)
plt.title("Attrition Distribution")
plt.show()

# %%
"""
The chart shows that 83.9% of employees remain in the company, while 16.1% have left

"""
# Out:
# '\nThe chart shows that 83.9% of employees remain in the company, while 16.1% have left\n\n'

# %% [markdown]
# ### 2) AGE DISTRIBUTION

# %%
plt.figure(figsize=(8, 5))
data['Age'].hist(bins=15, color="#FBAFE4", edgecolor='black')

plt.title('Age Distribution Histogram')
plt.xlabel('Age')
plt.ylabel('Headcount')
plt.tight_layout()
plt.show()

# %%
"""
    The age distribution shows that the largest group of employees is between 33 and 39 years old,
    bringing a solid level of experience. Meanwhile, those in older age groups can play an important,
    role by sharing their expertise and mentoring younger colleagues.
"""
# Out:
# '\n    The age distribution shows that the largest group of employees is between 33 and 39 years old,\n    bringing a solid level of experience. Meanwhile, those in older age groups can play an important,\n    role by sharing their expertise and mentoring younger colleagues.\n'

# %% [markdown]
# ### 3) ATTRITION DISTRIBUTION BY GENDER

# %%
attrition_rates = pd.crosstab(data['Gender'], data['Attrition'], normalize='index') * 100

sns.set(style="whitegrid")
colors = ["#FBAFE4", "#949494"]

plt.figure(figsize=(8, 5))
sns.countplot(x='Gender', hue='Attrition', data=data, palette=colors)

plt.title('Attrition Distribution by Gender')
plt.xlabel('Gender')
plt.ylabel('Headcount')
plt.legend(title='Attrition')
plt.tight_layout()
plt.show()

# %%
print(attrition_rates.round(2))
# Out:
# Attrition     No    Yes
# Gender
# Female     85.20  14.80
# Male       82.99  17.01

# %%
"""
The chart, it can be said that the number of male employees is higher than female employee.
While 14.8% of female employees left the company, t
The rate is 17.1% for male employees

so gender does not seem to be a significant factor in attrition

"""
# Out:
# '\nThe chart, it can be said that the number of male employees is higher than female employee.\nWhile 14.8% of female employees left the company, t\nThe rate is 17.1% for male employees\n\nso gender does not seem to be a significant factor in attrition\n\n'

# %% [markdown]
# ### 4) AVERAGE INCOME AND ATTRITION BY DEPARTMENT

# %%
avg_income_by_dept = data.groupby('Department')['MonthlyIncome'].mean().round(2)

colors = ["#FBAFE4", "#949494","#FF9F1C"]

plt.figure(figsize=(8, 5))
sns.barplot(x=avg_income_by_dept.index, y=avg_income_by_dept.values, palette=colors)

plt.title('Average Income by Department')
plt.xlabel('Department')
plt.ylabel('Average Income')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2373857486.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_income_by_dept.index, y=avg_income_by_dept.values, palette=colors)

# %%
print(avg_income_by_dept)
# Out:
# Department
# Human Resources           6654.51
# Research & Development    6281.25
# Sales                     6959.17
# Name: MonthlyIncome, dtype: float64

# %%
"""
observed that the Sales department has the highest average income,
followed by Human Resources, while Research & Development has the lowest

//-----> the lowest attrition rate is in  ( Research & Development ) , while the highest is in Sales


// ---->>  This is an important finding because it clearly shows that salary alone is not sufficient
           to ensure job satisfaction or retention bcz --->

           // -->  Factors such as working conditions, overtime, work environment may play a crucial role.
                   Based on this analysis, it is recommended to further examine the Sales department and
                   compare its conditions with those in Research & Development

"""
# Out:
# '\nobserved that the Sales department has the highest average income,\nfollowed by Human Resources, while Research & Development has the lowest\n\n//-----> the lowest attrition rate is in  ( Research & Development ) , while the highest is in Sales\n\n\n// ---->>  This is an important finding because it clearly shows that salary alone is not sufficient\n           to ensure job satisfaction or retention bcz --->\n\n           // -->  Factors such as working conditions, overtime, work environment may play a crucial role.\n                   Based on this analysis, it is recommended to further examine the Sales department and\n                   compare its conditions with those in Research & Development\n\n'

# %%
attrition_dept = data.groupby('Department')['Attrition'].apply(lambda x: (x == 'Yes').mean() * 100).round(2)


plt.figure(figsize=(8, 5))
sns.barplot(x=attrition_dept.index, y=attrition_dept.values, palette=colors)

plt.title('Attrition by Department')
plt.xlabel('Department')
plt.ylabel('Attrition')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2409817584.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=attrition_dept.index, y=attrition_dept.values, palette=colors)

# %%
print(attrition_dept)
# Out:
# Department
# Human Resources           19.05
# Research & Development    13.84
# Sales                     20.63
# Name: Attrition, dtype: float64

# %%
promoted_leavers = data[(data['Attrition']=='Yes') & (data['YearsSinceLastPromotion']==0)]
promoted_stayers = data[(data['Attrition']=='No') & (data['YearsSinceLastPromotion']==0)]

plt.figure(figsize=(10,6))
sns.histplot(promoted_stayers['Age'], bins=10, kde=True, color='green')
sns.histplot(promoted_leavers['Age'], bins=10, kde=True, color='salmon')
plt.title('Age Distribution of Employees Who Left After Promotion imediatly', fontsize=16)
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.show()

# %%
attrition_df = data[data['Attrition'] == 'Yes']
ax = sns.countplot(data , x = 'Attrition',hue = 'WorkLifeBalance')
plt.title('Work Life Balance vs Attrition')
# Out:
# Text(0.5, 1.0, 'Work Life Balance vs Attrition')

# %%
counts = attrition_df['EnvironmentSatisfaction'].value_counts()
plt.figure(figsize=(4,4))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=90)
plt.title('leavers Distribution by EnvironmentSatisfaction')
plt.show()

# %%
g = sns.catplot(
    data=data,
        x='OverTime',
        hue = 'Attrition',
        kind='count',
        height=10,
        aspect=3
)
for ax in g.axes.flatten():
    for p in ax.patches:
        ax.annotate(
            format(p.get_height(), '.0f'),
            (p.get_x() + p.get_width() / 2., p.get_height()),
            ha='center',
            va='bottom'
        )
g.set_titles("{row_name}")
g.set_axis_labels("Ovetime work", "Number of Employees")
plt.subplots_adjust(top=0.95)
plt.suptitle('Ovetime work vs Attrition ', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Ovetime work vs Attrition ')

# %%
data['Yearly_Salary'] = data['MonthlyIncome'] * 12
sns.boxplot(data=data,x = 'Gender',y = 'Yearly_Salary',hue='Attrition')
# Out:
# <Axes: xlabel='Gender', ylabel='Yearly_Salary'>

# %%
data.groupby(['YearsSinceLastPromotion','Attrition'])['Yearly_Salary'].median()
# Out:
# YearsSinceLastPromotion  Attrition
# 0                        No            56160.0
#                          Yes           32256.0
# 1                        No            60096.0
#                          Yes           34908.0
# 2                        No            50250.0
#                          Yes           41568.0
# 3                        No            60504.0
#                          Yes           88032.0
# 4                        No            83808.0
#                          Yes          114984.0
# 5                        No            68124.0
#                          Yes           82194.0
# 6                        No            75282.0
#                          Yes           95358.0
# 7                        No            67122.0
#                          Yes           65838.0
# 8                        No            89580.0
# 9                        No           118224.0
#                          Yes           82488.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # Features Selection / input

# %%
corr = df_for_model.corr(numeric_only=True)

plt.figure(figsize=(15, 7))
sns.heatmap(corr, annot=True, cmap="Blues", fmt=".1f")
plt.title("Correlation Heatmap of IBM Dataset")
plt.show()

# %%
# there are some unique columns that will not add any information to the model like
# EmployeeNumber
# EmployeeCount
# Over18
# StandardHours

# %%
df_for_model = data.copy()

# %%
df_for_model = data.drop(['EmployeeNumber','EmployeeCount','Over18','StandardHours'],axis=1)

# %%
df_for_model
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# ...

# %%
df_for_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
df_for_model['Attrition'] = df_for_model['Attrition'].replace({'Yes':1,"No":0})
# Out:
# /tmp/ipython-input-719475583.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_for_model['Attrition'] = df_for_model['Attrition'].replace({'Yes':1,"No":0})

# %% [markdown]
# ## Applying transformation to handle outliers

# %%
num_cols = df_for_model.select_dtypes(include='number').columns
n_cols = 3
n_rows = (len(num_cols) + n_cols - 1) // n_cols
plt.figure(figsize=(18, 5 * n_rows))
for i, col in enumerate(num_cols):
    plt.subplot(n_rows, n_cols, i + 1)
    sns.boxplot(x=df_for_model[col], color='skyblue')
    plt.title(f'Boxplot of {col}')

plt.tight_layout()
plt.show()

# %%
df_for_model['Yearly_Salary_transformed'] = np.sqrt(df_for_model['Yearly_Salary'])

# %%
df_for_model['MonthlyIncome_transformed'] = np.sqrt(df_for_model['MonthlyIncome'])

# %%
df_for_model['YearsSinceLastPromotion_transformed'] = np.log(np.cbrt(df_for_model['YearsSinceLastPromotion']+2))

# %%
df_for_model = df_for_model.drop(['Yearly_Salary','MonthlyIncome','YearsSinceLastPromotion'],axis = 1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_col= df_for_model.select_dtypes(include=['number'])
vif_data = pd.DataFrame()
vif_data['Feature'] = vif_col.columns
vif_data['VIF'] = [variance_inflation_factor(vif_col.values, i) for i in range(vif_col.shape[1])]
vif_data.sort_values(by = 'VIF',ascending=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                                 Feature         VIF
# 22            Yearly_Salary_transformed         inf
# 23            MonthlyIncome_transformed         inf
# 13                    PerformanceRating  122.830025
# 8                              JobLevel   48.286779
# 12                    PercentSalaryHike   42.301630
# 0                                   Age   33.264037
# 18                      WorkLifeBalance   15.367786
# 7                        JobInvolvement   14.999698
# 16                    TotalWorkingYears   14.056577
# 6                            HourlyRate   11.194665
# 19                       YearsAtCompany   10.203581
# 4                             Education    9.411091
# 24  YearsSinceLastPromotion_transformed    8.543557
# 14             RelationshipSatisfaction    7.250172
# ...

# %%
df_model_vif_treated = df_for_model.copy()

# %%
vif_col2= df_model_vif_treated.select_dtypes(include=['number'])

# %%
max_vif = 10

remove_flag = True

while remove_flag:
    vif = pd.DataFrame()
    vif["Feature"] = vif_col2.columns
    vif["VIF"] = [variance_inflation_factor(vif_col2.values, i) for i in range(vif_col2.shape[1])]

    max_vif_feature = vif.loc[vif['VIF'].idxmax()]

    if max_vif_feature['VIF'] > max_vif:
        vif_col2 = vif_col2.drop(max_vif_feature['Feature'], axis=1)
        print(f"Removed variable with high VIF: {max_vif_feature['Feature']} (VIF={max_vif_feature['VIF']})")
    else:
        # If no variable exceeds the threshold, set the flag to False to exit the loop
        remove_flag = False
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# Removed variable with high VIF: Yearly_Salary_transformed (VIF=inf)
# Removed variable with high VIF: PerformanceRating (VIF=122.83002527391469)
# Removed variable with high VIF: MonthlyIncome_transformed (VIF=87.37634322333473)
# Removed variable with high VIF: Age (VIF=31.98364660673379)
# Removed variable with high VIF: PercentSalaryHike (VIF=15.203005917153028)
# Removed variable with high VIF: WorkLifeBalance (VIF=13.806801432589848)
# Removed variable with high VIF: JobInvolvement (VIF=13.257150313344775)
# Removed variable with high VIF: JobLevel (VIF=11.463185983051163)
# Removed variable with high VIF: YearsAtCompany (VIF=10.037350207594018)

# %%
cat_df = df_model_vif_treated.select_dtypes(include=['object'])
df_after_vif = pd.concat([vif_col2, cat_df], axis=1)

df_after_vif
# Out:
#       Attrition  DailyRate  DistanceFromHome  Education  \
# 0             1       1102                 1          2
# 1             0        279                 8          1
# 2             1       1373                 2          2
# 3             0       1392                 3          4
# 4             0        591                 2          1
# ...         ...        ...               ...        ...
# 1465          0        884                23          2
# 1466          0        613                 6          1
# 1467          0        155                 4          3
# 1468          0       1023                 2          3
# 1469          0        628                 8          3
#
#       EnvironmentSatisfaction  HourlyRate  JobSatisfaction  MonthlyRate  \
# 0                           2          94                4        19479
# 1                           3          61                2        24907
# 2                           4          92                3         2396
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder , OneHotEncoder , StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## spliting the data

# %%
x = df_after_vif.drop('Attrition',axis=1)
y = df_after_vif['Attrition']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
#creating labelencoder
le = LabelEncoder()
col_to_label_encode = ['OverTime','Gender']
for col in col_to_label_encode:
    x_train[col] = le.fit_transform(x_train[col])
    x_test[col] = le.transform(x_test[col])

# %%
categorical_cols = ["BusinessTravel", "Department", "EducationField", "JobRole", "MaritalStatus"]

ohe = OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)

# Fit on train categorical features
x_train_ohe = ohe.fit_transform(x_train[categorical_cols])
x_test_ohe = ohe.transform(x_test[categorical_cols])

# Get the new column names
ohe_cols = ohe.get_feature_names_out(categorical_cols)

# Convert back to DataFrame
x_train_ohe = pd.DataFrame(x_train_ohe, columns=ohe_cols, index=x_train.index)
x_test_ohe = pd.DataFrame(x_test_ohe, columns=ohe_cols, index=x_test.index)

# Concatenate with the rest of the features
x_train_final = pd.concat([x_train.drop(categorical_cols, axis=1), x_train_ohe], axis=1)
x_test_final = pd.concat([x_test.drop(categorical_cols, axis=1), x_test_ohe], axis=1)

# %%
col_to_scal = ['DailyRate','DistanceFromHome','Education','HourlyRate','MonthlyRate','YearsSinceLastPromotion_transformed']
scale = StandardScaler()
for col in col_to_scal:
    x_train_final[[col]] = scale.fit_transform(x_train_final[[col]])
    x_test_final[[col]] = scale.transform(x_test_final[[col]])

# %% [markdown]
# # Model Training and Selection

# %% [markdown]
# ##LogisticRegression

# %%
log_reg = LogisticRegression(max_iter=1000, random_state=42)
log_reg.fit(x_train_final, y_train)

y_train_pred = log_reg.predict(x_train_final)
y_test_pred  = log_reg.predict(x_test_final)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc  = accuracy_score(y_test, y_test_pred)

print(f"Train Accuracy: {train_acc:.4f}")
print(f"Test Accuracy:  {test_acc:.4f}")
# Out:
# Train Accuracy: 0.8861
# Test Accuracy:  0.8571

# %% [markdown]
# ## KNN Classifer

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train_final, y_train)

y_train_pred = knn.predict(x_train_final)
y_test_pred  = knn.predict(x_test_final)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc  = accuracy_score(y_test, y_test_pred)

print(f"KNN Train Accuracy: {train_acc:.4f}")
print(f"KNN Test Accuracy:  {test_acc:.4f}")
# Out:
# KNN Train Accuracy: 0.8673
# KNN Test Accuracy:  0.8469

# %% [markdown]
# # cisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score


knn = DecisionTreeClassifier(random_state=42)
knn.fit(x_train_final, y_train)


y_train_pred = knn.predict(x_train_final)
y_test_pred  = knn.predict(x_test_final)


train_acc = accuracy_score(y_train, y_train_pred)
test_acc  = accuracy_score(y_test, y_test_pred)

# %%
print(f"KNN Train Accuracy: {train_acc:.4f}")
print(f"KNN Test Accuracy:  {test_acc:.4f}")
# Out:
# KNN Train Accuracy: 1.0000
# KNN Test Accuracy:  0.7619

# %%
# tart with Logistic Regression as a baseline → good interpretability, fast.

# Then try Decision Tree Classifier → handles complex patterns well.

# Optionally, use KNN Classifier if the dataset is small and distances are meaningful.

# %%
# Why we choose it:

# It is designed specifically for binary classification tasks (Attrition: Yes/No).

# Provides probability estimates, which helps HR interpret risk of attrition.

# Easy to interpret coefficients → Understand impact of each feature (e.g., age, salary).

# Computationally efficient → Suitable for medium-large datasets.

# %%
# Why we choose it:

# Captures non-linear relationships between features (e.g., certain combinations of workload and years at company).

# Easy to explain → "If condition A and B, then attrition = Yes".

# Works well with both numerical and categorical variables without much preprocessing.

# %%
# Why we could use it:

# Works well when data has clusters or natural grouping (i.e., similar employees behave similarly).

# Very simple to understand (no explicit model training).
